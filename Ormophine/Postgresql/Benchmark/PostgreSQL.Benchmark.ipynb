# %% [markdown]
# # PostgreSQL ORM CRUD Benchmark (Fair & Complete)
# This notebook benchmarks the performance of various Python ORMs (PonyORM, Ormophine, SQLAlchemy, Peewee) against a **PostgreSQL** database, testing full **CRUD** (Create, Read, Update, Delete) operations.
#
# ## Instructions
# 1. Run the **Setup & Prerequisites** cell to install PostgreSQL server and required Python libraries.
# 2. Run the **Import** cell to load the benchmark logic, plotting tools, and report generator.
# 3. Run the **Run Single Operation Benchmark** cell to see the chart and the execution report for single queries.
# 4. Run the **Run Batch Operation Benchmark** cell to see the chart and the execution report for batch queries (10000 records).

# %%
# Install PostgreSQL server
# !apt-get -y install postgresql > /dev/null 2>&1

# Start the PostgreSQL service
# !service postgresql start

# !sudo -u postgres psql -c "ALTER USER postgres WITH PASSWORD '1234';"

# Install Python dependencies
# !pip install psycopg[binary] Ormophine sqlalchemy pony peewee tqdm matplotlib numpy > /dev/null 2>&1

print('Setup complete! PostgreSQL is running and dependencies are installed.')

# %% [markdown]
# # Import Benchmark

# %%
from Ormophine.Postgresql.Benchmark import PostgreSQL_Benchmark
PostgreSQL_Benchmark.POSTGRES_CONFIG = {
    'host': '127.0.0.1',
    'user': 'root',
    'password': '',
    'database': 'test'
}

# %% [markdown]
# # Run Single Operation Benchmark (CRUD)

# %%
PostgreSQL_Benchmark.run_single_operation_benchmark(repeats=200, warmup_repeats=3, chunk_size=50)

# %% [markdown]
# # Run Batch Operation Benchmark (CUD)

# %%
PostgreSQL_Benchmark.run_batch_operation_benchmark(repeats=500, warmup_repeats=3, chunk_size=100)
